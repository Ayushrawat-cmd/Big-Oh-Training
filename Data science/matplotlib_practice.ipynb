# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./music.csv')

# %%
plt.bar(df['age'], df['gender'])
# Out:
# <BarContainer object of 18 artists>

# %%
plt.pie(df['genre'].value_counts(), labels=df['genre'].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x2d6c9cda090>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'HipHop'),
#   Text(-0.9526279870751434, 0.5499999256737774, 'Jazz'),
#   Text(-0.952627884085708, -0.5500001040567056, 'Classical'),
#   Text(1.5448414935947287e-07, -1.0999999999999892, 'Dance'),
#   Text(0.9526280385698485, -0.5499998364823061, 'Acoustic')])

# %% [markdown]
# # Box Plot
# >> A boxplot is a standardized way of displaying the distribution of data based on its five-number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). Boxplots can tell you about your outliers and their values, if your data is symmetrical, how tightly your data is grouped and if and how your data is skewed.
#
# >> Skewed data is data that creates an uneven curve distribution on a graph. We know data is skewed when the statistical distribution’s curve appears distorted to the left or right.

# %%
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2d6cd74ca10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2d6cd696290>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2d6cd73cc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2d6cd74f990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2d6cd7543d0>],
#  'means': []}

# %%
# df.plot(kind='bar', stacked=True, )
tmp_df = pd.DataFrame(np.array(df['genre'].value_counts()).reshape(1,5), columns=df['genre'].unique())
# plt.bar(df['genre'].unique(), df['genre'].value_counts())

# %%
tmp_df.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
plt.subplot(1,2,1)#row, col, index
plt.scatter(df['genre'],df['age'] )
plt.xlabel('genre')
plt.ylabel('age')


plt.subplot(1,2,2)
plt.scatter( df['gender'],df['age'])
plt.xlabel('gender')
# plt.ylabel('genre')
# Out:
# Text(0.5, 0, 'gender')

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
fig = plt.figure(figsize = (8,8))
ax = plt.axes(projection='3d')
ax.grid()
t = np.arange(0, 10*np.pi, np.pi/50)
x = np.sin(t)
y = np.cos(t)
# print(x,y)

ax.plot3D(x, y, t)
ax.set_title('3D Parametric Plot')

# Set axes label
ax.set_xlabel('x', labelpad=20)
ax.set_ylabel('y', labelpad=20)
ax.set_zlabel('t', labelpad=20)

plt.show()

# %%
plt.plot(df['age'], color='r', linestyle='dashed')
plt.title("age")
plt.legend(["age"])
plt.show()

# %%
ax = sns.lineplot(df['age'])
# Text annotation at x = 2, y = 1.75           
ax.arrow(8,37, dy=1 , dx =2, color='black')
ax.text(2, 27.5, "Custom text",
        
        rotation=-20,
       fontsize = 12,          # Size
       fontstyle = "oblique",  # Style
       color = "red",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment
# Out:
# Text(2, 27.5, 'Custom text')

# %%
time_df = pd.read_csv("./temprature.csv")

# %%
sns.lineplot(time_df['Date'])
# Out:
# <Axes: ylabel='Date'>

# %%
time_df['Date'] = pd.to_datetime(time_df['Date'])

# %%
idx = []
i = 0
for value in time_df['Daily minimum temperatures']:
    try:
        # arr.append(float(value))
        val = float(value)
    except Exception as error:
        idx.append(i)
        # print(error)
    i+=1

print(idx)
# Out:
# [565, 566, 1290]

# %%
time_df = time_df.drop(index=idx)

# %%
time_df['Daily minimum temperatures'] = time_df['Daily minimum temperatures'].astype(float)

# %%
sns.lineplot(x =time_df['Date'],y=  time_df['Daily minimum temperatures'])
width = 100
height = 8
sns.set(rc = {'figure.figsize':(width,height)})

# %% [markdown]
# # Error Bar
# >> This is done through the use of markers drawn over the original graph and its data points. Typically, Error bars are used to display either the standard deviation, standard error, confidence intervals or the minimum and maximum values in a ranged dataset.

# %%
sns.barplot(y =df['age'], x=df['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='age'>

# %% [markdown]
# >> Standard deviation error bars are the simplest to explain, because the standard deviation is a familiar statistic. It is the average distance from each data point to the sample mean. By default, errorbar="sd" will draw error bars at +/- 1 sd around the estimate, but the range can be increased by passing a scaling size parameter. Note that, assuming normally-distributed data, ~68% of the data will lie within one standard deviation, ~95% will lie within two, and ~99.7% will lie within three:

# %%
sns.pointplot(x=df['age'], errorbar='sd')
# Out:
# <Axes: xlabel='age'>

# %%
sns.scatterplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.regplot(y =df['age'], x=df['gender'])
width = 10
height = 4
sns.set(rc = {'figure.figsize':(width,height)})
