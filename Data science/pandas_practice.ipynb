# %% [markdown]
# # Import modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_8652\2080034654.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("music.csv")

# %%
df.head()
# Out:
#    age  gender   genre
# 0   20       1  HipHop
# 1   23       1  HipHop
# 2   25       1  HipHop
# 3   26       1    Jazz
# 4   29       1    Jazz

# %%
df.dtypes
# Out:
# age        int64
# gender     int64
# genre     object
# dtype: object

# %%
df.get("age")
# Out:
# 0     20
# 1     23
# 2     25
# 3     26
# 4     29
# 5     30
# 6     31
# 7     33
# 8     37
# 9     20
# 10    21
# 11    25
# 12    26
# 13    27
# 14    30
# 15    31
# 16    34
# 17    35
# Name: age, dtype: int64

# %%
df.get(["age","genre"])
# Out:
#     age      genre
# 0    20     HipHop
# 1    23     HipHop
# 2    25     HipHop
# 3    26       Jazz
# 4    29       Jazz
# 5    30       Jazz
# 6    31  Classical
# 7    33  Classical
# 8    37  Classical
# 9    20      Dance
# 10   21      Dance
# 11   25      Dance
# 12   26   Acoustic
# 13   27   Acoustic
# 14   30   Acoustic
# 15   31  Classical
# 16   34  Classical
# 17   35  Classical

# %%
df.where(df["age"]>30).dropna()
# Out:
#      age  gender      genre
# 6   31.0     1.0  Classical
# 7   33.0     1.0  Classical
# 8   37.0     1.0  Classical
# 15  31.0     0.0  Classical
# 16  34.0     0.0  Classical
# 17  35.0     0.0  Classical

# %%
df[["age","gender"]].iloc[np.arange(5,10)]
# Out:
#    age  gender
# 5   30       1
# 6   31       1
# 7   33       1
# 8   37       1
# 9   20       0

# %%
df.isna()
# Out:
#       age  gender  genre
# 0   False   False  False
# 1   False   False  False
# 2   False   False  False
# 3   False   False  False
# 4   False   False  False
# 5   False   False  False
# 6   False   False  False
# 7   False   False  False
# 8   False   False  False
# 9   False   False  False
# 10  False   False  False
# 11  False   False  False
# 12  False   False  False
# 13  False   False  False
# 14  False   False  False
# 15  False   False  False
# 16  False   False  False
# 17  False   False  False

# %%
df.drop_duplicates()
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
df["age"].astype(float)
# Out:
# 0     20.0
# 1     23.0
# 2     25.0
# 3     26.0
# 4     29.0
# 5     30.0
# 6     31.0
# 7     33.0
# 8     37.0
# 9     20.0
# 10    21.0
# 11    25.0
# 12    26.0
# 13    27.0
# 14    30.0
# 15    31.0
# 16    34.0
# 17    35.0
# Name: age, dtype: float64

# %%
df["number"] = np.arange(0,18)
df.head()
# Out:
#    age  gender   genre  number
# 0   20       1  HipHop       0
# 1   23       1  HipHop       1
# 2   25       1  HipHop       2
# 3   26       1    Jazz       3
# 4   29       1    Jazz       4

# %%
df.rename(columns={"number":"num"})
# Out:
#     age  gender      genre  num
# 0    20       1     HipHop    0
# 1    23       1     HipHop    1
# 2    25       1     HipHop    2
# 3    26       1       Jazz    3
# 4    29       1       Jazz    4
# 5    30       1       Jazz    5
# 6    31       1  Classical    6
# 7    33       1  Classical    7
# 8    37       1  Classical    8
# 9    20       0      Dance    9
# 10   21       0      Dance   10
# 11   25       0      Dance   11
# 12   26       0   Acoustic   12
# 13   27       0   Acoustic   13
# 14   30       0   Acoustic   14
# 15   31       0  Classical   15
# 16   34       0  Classical   16
# 17   35       0  Classical   17

# %%
df.sort_values(["genre", "age"])
# Out:
#     age  gender      genre  number
# 12   26       0   Acoustic      12
# 13   27       0   Acoustic      13
# 14   30       0   Acoustic      14
# 6    31       1  Classical       6
# 15   31       0  Classical      15
# 7    33       1  Classical       7
# 16   34       0  Classical      16
# 17   35       0  Classical      17
# 8    37       1  Classical       8
# 9    20       0      Dance       9
# 10   21       0      Dance      10
# 11   25       0      Dance      11
# 0    20       1     HipHop       0
# 1    23       1     HipHop       1
# 2    25       1     HipHop       2
# 3    26       1       Jazz       3
# 4    29       1       Jazz       4
# 5    30       1       Jazz       5

# %%
df.groupby("genre").describe()
# Out:
#             age                                                     gender  \
#           count       mean       std   min   25%   50%    75%   max  count
# genre
# Acoustic    3.0  27.666667  2.081666  26.0  26.5  27.0  28.50  30.0    3.0
# Classical   6.0  33.500000  2.345208  31.0  31.5  33.5  34.75  37.0    6.0
# Dance       3.0  22.000000  2.645751  20.0  20.5  21.0  23.00  25.0    3.0
# HipHop      3.0  22.666667  2.516611  20.0  21.5  23.0  24.00  25.0    3.0
# Jazz        3.0  28.333333  2.081666  26.0  27.5  29.0  29.50  30.0    3.0
#
#                 ...           number                                           \
#           mean  ...  75%  max  count  mean      std   min    25%   50%    75%
# genre           ...
# Acoustic   0.0  ...  0.0  0.0    3.0  13.0  1.00000  12.0  12.50  13.0  13.50
# Classical  0.5  ...  1.0  1.0    6.0  11.5  5.00999   6.0   7.25  11.5  15.75
# Dance      0.0  ...  0.0  0.0    3.0  10.0  1.00000   9.0   9.50  10.0  10.50
# ...

# %%
addition = lambda a : a.mean()
df.groupby("genre").agg(addition)
# Out:
#                  age  gender  number
# genre
# Acoustic   27.666667     0.0    13.0
# Classical  33.500000     0.5    11.5
# Dance      22.000000     0.0    10.0
# HipHop     22.666667     1.0     1.0
# Jazz       28.333333     1.0     4.0

# %%
plt.hist(df["age"])
# Out:
# (array([3., 1., 2., 2., 1., 3., 2., 1., 2., 1.]),
#  array([20. , 21.7, 23.4, 25.1, 26.8, 28.5, 30.2, 31.9, 33.6, 35.3, 37. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x = df["age"], y = df["gender"])
plt.xlabel("age")
plt.ylabel("gender")
# Out:
# Text(0, 0.5, 'gender')

# %%
plt.plot(df["age"])

# %%
df1 = pd.read_csv('demo.csv')

# %%
pd.merge(df,df1,how='inner', on='number')
# Out:
#     age  gender      genre  number   name
# 0    20       1     HipHop       0  ayush
# 1    23       1     HipHop       1    fsd
# 2    25       1     HipHop       2    dfs
# 3    26       1       Jazz       3    sfd
# 4    29       1       Jazz       4    dfs
# 5    30       1       Jazz       5     sf
# 6    31       1  Classical       6     sf
# 7    33       1  Classical       7     sf
# 8    37       1  Classical       8     sf
# 9    20       0      Dance       9     sf
# 10   21       0      Dance      10     sf
# 11   25       0      Dance      11     sf
# 12   26       0   Acoustic      12     sf
# 13   27       0   Acoustic      13     sf
# 14   30       0   Acoustic      14     sf
# 15   31       0  Classical      15     sf
# 16   34       0  Classical      16     sf
# 17   35       0  Classical      17     sf

# %%
pd.merge(df,df1,'inner',left_index=True, right_index=True)
# Out:
#     age  gender      genre  number_x  number_y   name
# 0    20       1     HipHop         0         0  ayush
# 1    23       1     HipHop         1         1    fsd
# 2    25       1     HipHop         2         2    dfs
# 3    26       1       Jazz         3         3    sfd
# 4    29       1       Jazz         4         4    dfs
# 5    30       1       Jazz         5         5     sf
# 6    31       1  Classical         6         6     sf
# 7    33       1  Classical         7         7     sf
# 8    37       1  Classical         8         8     sf
# 9    20       0      Dance         9         9     sf
# 10   21       0      Dance        10        10     sf
# 11   25       0      Dance        11        11     sf
# 12   26       0   Acoustic        12        12     sf
# 13   27       0   Acoustic        13        13     sf
# 14   30       0   Acoustic        14        14     sf
# 15   31       0  Classical        15        15     sf
# ...

# %%
pd.pivot_table(df,index=['genre', 'age'])
# Out:
#                gender  number
# genre     age
# Acoustic  26      0.0    12.0
#           27      0.0    13.0
#           30      0.0    14.0
# Classical 31      0.5    10.5
#           33      1.0     7.0
#           34      0.0    16.0
#           35      0.0    17.0
#           37      1.0     8.0
# Dance     20      0.0     9.0
#           21      0.0    10.0
#           25      0.0    11.0
# HipHop    20      1.0     0.0
#           23      1.0     1.0
#           25      1.0     2.0
# Jazz      26      1.0     3.0
#           29      1.0     4.0
#           30      1.0     5.0

# %%
pd.melt(df)
# Out:
#    variable value
# 0       age    20
# 1       age    23
# 2       age    25
# 3       age    26
# 4       age    29
# ..      ...   ...
# 67   number    13
# 68   number    14
# 69   number    15
# 70   number    16
# 71   number    17
#
# [72 rows x 2 columns]

# %%
df.unstack(level=1)
# Out:
# age     0     20
#         1     23
#         2     25
#         3     26
#         4     29
#               ..
# number  13    13
#         14    14
#         15    15
#         16    16
#         17    17
# Length: 72, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
le = LabelEncoder()
le.fit(df['genre'])
# Out:
# LabelEncoder()

# %%
new_df = df
new_df["genre"] = le.transform(df["genre"])

# %%
df = pd.read_csv("./music.csv")

# %%
from sklearn.compose import ColumnTransformer

# %%
enc = OneHotEncoder()
enc.fit_transform(df[["genre"]])
# Out:
# <18x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>

# %%
def oneHotEncoder(series, cols):
    columnTranformer = ColumnTransformer([('encoder', OneHotEncoder(),cols )], remainder='passthrough')
    return columnTranformer.fit_transform(series)

# %%
def top_x(df2,variable,top_x_labels):
    for label in top_x_labels:
        df2[variable+'_'+label] = np.where(df[variable]==label,1,0)

# %%
def encodingSelection(X, threshold = 10):
    string_cols = list(np.where(X.dtypes == object))[0]
    oneHotEncoding_indices = []
    for col in string_cols:
        # length = len(pd.unique(X[X.columns[col]]))
        # if length == 2 or length > threshold:
        #     X[X.columns[col]] = LabelencoderMethod(X[X.columns[col]])
        # else:
        oneHotEncoding_indices.append(col)
    
    X = oneHotEncoder(X, oneHotEncoding_indices)
    return X

# %%
df2 =top_x(df, 'genre', df['genre'].unique())

# %%
df
# Out:
#     age  gender      genre  genre_HipHop  genre_Jazz  genre_Classical  \
# 0    20       1     HipHop             1           0                0
# 1    23       1     HipHop             1           0                0
# 2    25       1     HipHop             1           0                0
# 3    26       1       Jazz             0           1                0
# 4    29       1       Jazz             0           1                0
# 5    30       1       Jazz             0           1                0
# 6    31       1  Classical             0           0                1
# 7    33       1  Classical             0           0                1
# 8    37       1  Classical             0           0                1
# 9    20       0      Dance             0           0                0
# 10   21       0      Dance             0           0                0
# 11   25       0      Dance             0           0                0
# ...

# %%
new_df = encodingSelection(df)

# %%
df['genre'].value_counts()
# Out:
# genre
# Classical    6
# HipHop       3
# Jazz         3
# Dance        3
# Acoustic     3
# Name: count, dtype: int64

# %%
temp_df = pd.read_csv("./temprature.csv")

# %%
temp_df.dtypes
# Out:
# Date                          object
# Daily minimum temperatures    object
# dtype: object

# %%
temp_df.shape
# Out:
# (3650, 2)

# %%
arr = []
idx = []
i = 0
for value in temp_df['Daily minimum temperatures']:
    try:
        arr.append(float(value))
    except Exception as error:
        idx.append(i)
        print(error)
    i+=1

print(arr)
print(idx)
# Out:
# could not convert string to float: '?0.2'
# could not convert string to float: '?0.8'
# could not convert string to float: '?0.1'
# ...

# %%
temp_df = temp_df.drop(index=idx)

# %%
temp_df['Daily minimum temperatures'] = temp_df['Daily minimum temperatures'].astype(dtype=float)

# %%
temp_df.dtypes
# Out:
# Date                           object
# Daily minimum temperatures    float64
# dtype: object

# %%
temp_df.head()
# Out:
#        Date  Daily minimum temperatures
# 0  1/1/1981                        20.7
# 1  1/2/1981                        17.9
# 2  1/3/1981                        18.8
# 3  1/4/1981                        14.6
# 4  1/5/1981                        15.8

# %%
temp_df['Month'] = pd.DatetimeIndex(temp_df['Date']).month

# %%
temp_df.groupby('Month').describe()
# Out:
#       Daily minimum temperatures                                           \
#                            count       mean       std  min     25%    50%
# Month
# 1                          310.0  15.030323  2.872859  8.5  13.000  14.80
# 2                          282.0  15.373759  2.742785  9.2  13.600  15.05
# 3                          310.0  14.565484  3.193744  7.4  12.125  14.30
# 4                          300.0  12.088333  3.082299  5.7   9.800  11.95
# 5                          310.0   9.866452  2.793387  2.1   8.000  10.00
# 6                          300.0   7.278333  2.643746  0.0   5.700   7.45
# 7                          307.0   6.754397  2.564171  0.0   5.000   7.00
# 8                          310.0   7.891290  2.334022  1.7   6.425   8.00
# 9                          300.0   8.976333  2.795901  3.0   6.900   8.90
# 10                         310.0  10.309355  2.687778  4.7   8.500  10.05
# 11                         300.0  12.479667  2.957246  5.7  10.500  12.20
# ...

# %% [markdown]
# # Rolling mean

# %%
temp_df['Daily minimum temperatures'].rolling(2).mean()
# Out:
# 0         NaN
# 1       19.30
# 2       18.35
# 3       16.70
# 4       15.20
#         ...
# 3645    14.30
# 3646    13.80
# 3647    13.55
# 3648    14.60
# 3649    14.35
# Name: Daily minimum temperatures, Length: 3647, dtype: float64

# %%
temp_df['Date'] = pd.to_datetime(temp_df['Date'])

# %%
temp_df.dtypes
# Out:
# Date                          datetime64[ns]
# Daily minimum temperatures           float64
# Month                                  int32
# dtype: object

# %%
def slice_date(df,col,start_date, end_date):
    mask = (df[col] > start_date) & (df[col] <= end_date)
    return mask

# temp_df.set_index(['Date']).loc['1981-23-04':'1981-23-05',: ]
temp_df.loc[slice_date(temp_df, 'Date',pd.to_datetime('1981-12-04'),pd.to_datetime('1981-12-23') )  ]
# Out:
#           Date  Daily minimum temperatures  Month
# 338 1981-12-05                        13.0     12
# 339 1981-12-06                        15.0     12
# 340 1981-12-07                        14.7     12
# 341 1981-12-08                        12.6     12
# 342 1981-12-09                        12.5     12
# 343 1981-12-10                        13.5     12
# 344 1981-12-11                        14.8     12
# 345 1981-12-12                        17.2     12
# 346 1981-12-13                         9.7     12
# 347 1981-12-14                        12.1     12
# 348 1981-12-15                        12.8     12
# 349 1981-12-16                        11.2     12
# 350 1981-12-17                        16.4     12
# 351 1981-12-18                        15.6     12
# 352 1981-12-19                        13.3     12
# 353 1981-12-20                        11.0     12
# 354 1981-12-21                        11.1     12
# 355 1981-12-22                        15.0     12
# ...
